# %% [markdown]
# # **Installing Libraries (Optional)**

# %%
# !pip install pandas
# !pip install numpy
# !pip install requests
# !pip install selenium
# !pip install webdriver-manager
# !pip install beautifulsoup4
# !pip install seaborn
# !pip install matplotlib
# !pip install scikit-learn
# !pip install nltk

# %% [markdown]
# #  **Import neccessery libraries**

# %%
import re
import pandas as pd
import numpy as np
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from mpl_toolkits.mplot3d import Axes3D
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.model_selection import train_test_split

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# #  **Web Scraping from Amazon website**
#
# Since pulling the data from the site takes hours, we pulled the data once and exported it to a CSV file

# %%
My_User_Agent  = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
headers = {
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': My_User_Agent,
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://www.amazon.com/',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
}

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument("--log-level=3")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument("--disable-blink-features=AutomationControlled")

# Driver Setting to notice. 
try:driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
except:driver = webdriver.Chrome()

# Looping Through Pages
listofdict = list()
Listing_count= 7000 
Listing_start = 1
Script_Break = False
Full_Break = False
pages = range(1,100)
for page in pages:
    if Full_Break == True:
        break

    driver.get('https://www.amazon.com/')
    time.sleep(2)
    Page_URL = f"https://www.amazon.com/s?i=electronics-intl-ship&bbn=16225009011&rh=n%3A16225009011%2Cn%3A541966&page={page}&qid=1709158259&ref=sr_pg_1"
    driver.get(Page_URL)
    time.sleep(3)

    response = driver.page_source
    soup = BeautifulSoup(response, "html.parser")

    Results = soup.find_all('div',class_='sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20')
    # Looping Through Each Product
    for data in Results:
        if Script_Break == True:
            Full_Break = True
            break

        try:
            Product_Link = data.find('a', class_='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal').get('href')
            Full_Link = 'https://www.amazon.com' + Product_Link

            driver.get(Full_Link)
            time.sleep(2)

            Product_response = driver.page_source
            Product_Soup = BeautifulSoup(Product_response, "html.parser")

            #Getting Data 
            product_name = Product_Soup.find('span', id="productTitle").text.strip()
            product_price = Product_Soup.find('span', class_='aok-offscreen').text
            try:
                product_Description = Product_Soup.find('div', id='aplus').text.strip()
            except:
                product_Description = Product_Soup.find('div', id='apm-brand-story-carousel').text.strip()
            review_link = Product_Soup.find('a', class_='a-link-emphasis a-text-bold').get('href')
      
            review_url = 'https://www.amazon.com' + review_link
            driver.get(review_url)
            time.sleep(2)

            review_response = driver.page_source
            review_soup = BeautifulSoup(review_response, "html.parser")
            all_reviews = review_soup.find_all('div', class_='a-section review aok-relative')
            
            for review_data in all_reviews:
                datadict = dict()
                datadict['Product Name'] = product_name
                datadict['Product Price'] = product_price
                datadict['Product Description'] = product_Description
                datadict['Product ID'] = Full_Link.split('/')[5]
                datadict['Brand'] =review_soup.find('a', class_='a-size-base a-link-normal').text
                datadict['Rating'] =review_data.find('span', class_='a-icon-alt').text.split(' ')[0]
                datadict['Date'] =review_data.find('span', class_='a-size-base a-color-secondary review-date').text.split(' on ')[1]
                datadict['customer reviews'] =review_data.find('span', class_='a-size-base review-text review-text-content').text.strip()
                print(datadict)
                listofdict.append(datadict)
                print('Listing Number......', Listing_start)
                if Listing_start >= Listing_count:
                    Script_Break = True
                    break
                Listing_start = Listing_start+1
        except:
            pass

df = pd.DataFrame.from_dict(listofdict)
path = 'Amazon_Data.csv'
df.to_csv(path ,index=False)
print(f'Data Saved in {path}')

# %% [markdown]
# # Data Loading and Preprocessing

# %% [markdown]
# Reading data from CSV file and making a DataFrame df from it.

# %%
df = pd.read_csv("C:/Users/rotes/Desktop/Amazon_Data.csv")
df.head()
# Out:
#                                         Product Name Product Price  \
# 0  Amazon Basics Micro SDXC Memory Card with Full...      $17.92
# 1  Amazon Basics Micro SDXC Memory Card with Full...      $17.92
# 2  Amazon Basics Micro SDXC Memory Card with Full...      $17.92
# 3  Amazon Basics Micro SDXC Memory Card with Full...      $17.92
# 4  Amazon Basics Micro SDXC Memory Card with Full...      $17.92
#
#                                  Product Description  Product ID  \
# 0  From the brand \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n...  B08TJRVWV1
# 1  From the brand \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n...  B08TJRVWV1
# 2  From the brand \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n...  B08TJRVWV1
# 3  From the brand \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n...  B08TJRVWV1
# 4  From the brand \n\n\n\n\n\n\n\n\n\n \n\n\n\n\n...  B08TJRVWV1
#
#            Brand  Rating               Date  \
# 0  Amazon Basics     5.0  December 15, 2023
# 1  Amazon Basics     5.0   February 8, 2024
# 2  Amazon Basics     5.0    January 6, 2024
# 3  Amazon Basics     4.0        May 1, 2023
# 4  Amazon Basics     5.0  February 25, 2024
#
#                                     customer reviews
# 0  n a world obsessed with flashy brands and exor...
# 1  Plenty of room and works and great price. No i...
# 2  Works really well. I use it for my dash cam an...
# 3  The Amazon Basics microSDXC Memory Card with F...
# 4  Nice card good for security cameras , adapters...

# %% [markdown]
# Dropping Null Values rows
#
# *   Dropping Date column as its not Relevant
# *   Removing new line variable from Product Description
# *   Removing dollar sign from Product Price
# *   Converting Product Price from string to integer
# *   Dropping Null Values rows after processing
# *   Dropping Product Description
#
# ---

# %%
df.dropna(inplace=True)
df.drop('Date', axis=1, inplace=True)
df.drop('Product Description', axis=1, inplace=True)
df['Product Price'] = df['Product Price'].str.replace('$', '')
df['Product Price'] = df['Product Price'].apply(lambda x: re.findall(r'\d+\.\d+', str(x)))
df['Product Price'] = df['Product Price'].apply(lambda x: float(x[0]) if len(x) > 0 else None)
df.dropna(inplace=True)
df
# Out:
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\845160744.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Product Price'] = df['Product Price'].str.replace('$', '')
#                                            Product Name  Product Price  \
# 0     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 1     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 2     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 3     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 4     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# ...                                                 ...            ...
# 6995  be quiet! Dark Rock Pro 4 250W TDP CPU Cooler ...          91.99
# 6996  be quiet! Dark Rock Pro 4 250W TDP CPU Cooler ...          91.99
# 6997  LG Electronics BP60NB10 Ultra Slim Portable Hy...         129.99
# 6998  LG Electronics BP60NB10 Ultra Slim Portable Hy...         129.99
# 6999  LG Electronics BP60NB10 Ultra Slim Portable Hy...         129.99
#
#       Product ID           Brand  Rating  \
# 0     B08TJRVWV1   Amazon Basics     5.0
# 1     B08TJRVWV1   Amazon Basics     5.0
# 2     B08TJRVWV1   Amazon Basics     5.0
# 3     B08TJRVWV1   Amazon Basics     4.0
# 4     B08TJRVWV1   Amazon Basics     5.0
# ...          ...             ...     ...
# 6995  B07BY6F8D9       be quiet!     3.0
# 6996  B07BY6F8D9       be quiet!     5.0
# 6997  B079LTC6ML  LG Electronics     5.0
# 6998  B079LTC6ML  LG Electronics     5.0
# 6999  B079LTC6ML  LG Electronics     4.0
#
#                                        customer reviews
# 0     n a world obsessed with flashy brands and exor...
# 1     Plenty of room and works and great price. No i...
# 2     Works really well. I use it for my dash cam an...
# 3     The Amazon Basics microSDXC Memory Card with F...
# 4     Nice card good for security cameras , adapters...
# ...                                                 ...
# 6995  So first thing first, I am leaving the review ...
# 6996  Purchased this for use with an ASUS Rog Strix ...
# 6997  When I received the drive today, there was no ...
# 6998  When I am not traveling it is used like any ot...
# 6999  I picked this drive because I recognize LG's b...
#
# [6977 rows x 6 columns]

# %% [markdown]
# Visualizing Brand percentage and their weithage in dataset

# %%
brand_counts = df['Brand'].value_counts()
percentages = brand_counts / len(df) * 100
plt.figure(figsize=(10, 8))
patches, _ = plt.pie(brand_counts, startangle=140)
plt.title('Percentage of Data by Brand')
plt.axis('equal')
legend_labels = [f'{brand}: {percent:.1f}%' for brand, percent in zip(brand_counts.index, percentages)]
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=f'C{i}', markersize=10) for i in range(len(brand_counts))]
plt.legend(legend_handles, legend_labels, loc='upper left', fontsize='small', title='Brand - Percentage', ncol=2)
plt.show()

# %%
df.head()
# Out:
#                                         Product Name  Product Price  \
# 0  Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 1  Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 2  Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 3  Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 4  Amazon Basics Micro SDXC Memory Card with Full...          17.92
#
#    Product ID          Brand  Rating  \
# 0  B08TJRVWV1  Amazon Basics     5.0
# 1  B08TJRVWV1  Amazon Basics     5.0
# 2  B08TJRVWV1  Amazon Basics     5.0
# 3  B08TJRVWV1  Amazon Basics     4.0
# 4  B08TJRVWV1  Amazon Basics     5.0
#
#                                     customer reviews
# 0  n a world obsessed with flashy brands and exor...
# 1  Plenty of room and works and great price. No i...
# 2  Works really well. I use it for my dash cam an...
# 3  The Amazon Basics microSDXC Memory Card with F...
# 4  Nice card good for security cameras , adapters...

# %% [markdown]
# Visualizing Relationship Between Brand and Rating

# %%
plt.figure(figsize=(20, 5))
sns.scatterplot(x='Brand', y='Rating', hue='Brand', data=df, palette='viridis', legend=False)
plt.title('Relationship between Brand and Rating')
plt.xlabel('Brand')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Applying nltk to get useful words from reviews and remove all useless words

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    if pd.notnull(text):
        words = word_tokenize(str(text).lower())
        words = [word for word in words if word.isalpha() and word not in stop_words]
        words = [lemmatizer.lemmatize(word) for word in words]
        return ' '.join(words)
    else:
        return ''
df['clean_reviews'] = df['customer reviews'].apply(preprocess_text)
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rotes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rotes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rotes\AppData\Roaming\nltk_data...
#                                            Product Name  Product Price  \
# 0     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 1     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 2     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 3     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# 4     Amazon Basics Micro SDXC Memory Card with Full...          17.92
# ...                                                 ...            ...
# 6995  be quiet! Dark Rock Pro 4 250W TDP CPU Cooler ...          91.99
# 6996  be quiet! Dark Rock Pro 4 250W TDP CPU Cooler ...          91.99
# 6997  LG Electronics BP60NB10 Ultra Slim Portable Hy...         129.99
# 6998  LG Electronics BP60NB10 Ultra Slim Portable Hy...         129.99
# 6999  LG Electronics BP60NB10 Ultra Slim Portable Hy...         129.99
#
#       Product ID           Brand  Rating  \
# 0     B08TJRVWV1   Amazon Basics     5.0
# 1     B08TJRVWV1   Amazon Basics     5.0
# 2     B08TJRVWV1   Amazon Basics     5.0
# 3     B08TJRVWV1   Amazon Basics     4.0
# 4     B08TJRVWV1   Amazon Basics     5.0
# ...          ...             ...     ...
# 6995  B07BY6F8D9       be quiet!     3.0
# 6996  B07BY6F8D9       be quiet!     5.0
# 6997  B079LTC6ML  LG Electronics     5.0
# 6998  B079LTC6ML  LG Electronics     5.0
# 6999  B079LTC6ML  LG Electronics     4.0
#
#                                        customer reviews  \
# 0     n a world obsessed with flashy brands and exor...
# 1     Plenty of room and works and great price. No i...
# 2     Works really well. I use it for my dash cam an...
# 3     The Amazon Basics microSDXC Memory Card with F...
# 4     Nice card good for security cameras , adapters...
# ...                                                 ...
# 6995  So first thing first, I am leaving the review ...
# 6996  Purchased this for use with an ASUS Rog Strix ...
# 6997  When I received the drive today, there was no ...
# 6998  When I am not traveling it is used like any ot...
# 6999  I picked this drive because I recognize LG's b...
#
#                                           clean_reviews
# 0     n world obsessed flashy brand exorbitant price...
# 1                    plenty room work great price issue
# 2     work really well use dash cam problem good pri...
# 3     amazon basic microsdxc memory card full size a...
# 4     nice card good security camera adapter work great
# ...                                                 ...
# 6995  first thing first leaving review bequiet dark ...
# 6996  purchased use asus rog strix motherboard amd c...
# 6997  received drive today surrounding box cushionin...
# 6998  traveling used like drive video editing disc b...
# 6999  picked drive recognize lg brand could find sol...
#
# [6977 rows x 7 columns]

# %% [markdown]
# Applying TF-IDF method on
#
#
# *   clean_reivews
# *   Product Name
#
# to convert Text base data to meaningfull infromation

# %%
vectorizer = TfidfVectorizer()
text_col = ['clean_reviews','Product Name']
for col in text_col:
  X = vectorizer.fit_transform(df[col])
  tfidf_sum = X.sum(axis=1)
  df[col] = tfidf_sum
df
# Out:
#       Product Name  Product Price  Product ID           Brand  Rating  \
# 0         4.324424          17.92  B08TJRVWV1   Amazon Basics     5.0
# 1         4.324424          17.92  B08TJRVWV1   Amazon Basics     5.0
# 2         4.324424          17.92  B08TJRVWV1   Amazon Basics     5.0
# 3         4.324424          17.92  B08TJRVWV1   Amazon Basics     4.0
# 4         4.324424          17.92  B08TJRVWV1   Amazon Basics     5.0
# ...            ...            ...         ...             ...     ...
# 6995      5.258003          91.99  B07BY6F8D9       be quiet!     3.0
# 6996      5.258003          91.99  B07BY6F8D9       be quiet!     5.0
# 6997      4.927637         129.99  B079LTC6ML  LG Electronics     5.0
# 6998      4.927637         129.99  B079LTC6ML  LG Electronics     5.0
# 6999      4.927637         129.99  B079LTC6ML  LG Electronics     4.0
#
#                                        customer reviews  clean_reviews
# 0     n a world obsessed with flashy brands and exor...      11.454248
# 1     Plenty of room and works and great price. No i...       2.346163
# 2     Works really well. I use it for my dash cam an...       4.394686
# 3     The Amazon Basics microSDXC Memory Card with F...       7.200007
# 4     Nice card good for security cameras , adapters...       2.690539
# ...                                                 ...            ...
# 6995  So first thing first, I am leaving the review ...      12.104805
# 6996  Purchased this for use with an ASUS Rog Strix ...       8.884165
# 6997  When I received the drive today, there was no ...       8.610333
# 6998  When I am not traveling it is used like any ot...       5.724546
# 6999  I picked this drive because I recognize LG's b...      10.456199
#
# [6977 rows x 7 columns]

# %% [markdown]
# Performing Sentiment analysis on the bases of rating and sentiment analyzer

# %%
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
def get_sentiment_score(text, rating):
    if rating > 3:
        return 'Positive'
    elif rating < 3:
        return 'Negative'
    else:
        sentiment = analyzer.polarity_scores(text)
        if sentiment['compound'] >= 0.05:
            return 'Positive'
        elif sentiment['compound'] <= -0.05:
            return 'Negative'
        else:
            return 'Neutral'
df['sentiment'] = df.apply(lambda row: get_sentiment_score(row['customer reviews'], row['Rating']), axis=1)
df[['Product Name', 'Rating', 'customer reviews', 'sentiment']]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rotes\AppData\Roaming\nltk_data...
#       Product Name  Rating                                   customer reviews  \
# 0         4.324424     5.0  n a world obsessed with flashy brands and exor...
# 1         4.324424     5.0  Plenty of room and works and great price. No i...
# 2         4.324424     5.0  Works really well. I use it for my dash cam an...
# 3         4.324424     4.0  The Amazon Basics microSDXC Memory Card with F...
# 4         4.324424     5.0  Nice card good for security cameras , adapters...
# ...            ...     ...                                                ...
# 6995      5.258003     3.0  So first thing first, I am leaving the review ...
# 6996      5.258003     5.0  Purchased this for use with an ASUS Rog Strix ...
# 6997      4.927637     5.0  When I received the drive today, there was no ...
# 6998      4.927637     5.0  When I am not traveling it is used like any ot...
# 6999      4.927637     4.0  I picked this drive because I recognize LG's b...
#
#      sentiment
# 0     Positive
# 1     Positive
# 2     Positive
# 3     Positive
# 4     Positive
# ...        ...
# 6995  Negative
# 6996  Positive
# 6997  Positive
# 6998  Positive
# 6999  Positive
#
# [6977 rows x 4 columns]

# %% [markdown]
# Applying Label Encoding on
#
# * Brand
# * Product ID
# * Sentiment

# %%
brand_encoder = LabelEncoder()
df['Brand_encode'] = brand_encoder.fit_transform(df['Brand'])
product_id_encoder = LabelEncoder()
df['Product ID'] = product_id_encoder.fit_transform(df['Product ID'])
df.head()
df['sentiment_encoded'] = product_id_encoder.fit_transform(df['sentiment'])
df.head()
# Out:
#    Product Name  Product Price  Product ID          Brand  Rating  \
# 0      4.324424          17.92         356  Amazon Basics     5.0
# 1      4.324424          17.92         356  Amazon Basics     5.0
# 2      4.324424          17.92         356  Amazon Basics     5.0
# 3      4.324424          17.92         356  Amazon Basics     4.0
# 4      4.324424          17.92         356  Amazon Basics     5.0
#
#                                     customer reviews  clean_reviews sentiment  \
# 0  n a world obsessed with flashy brands and exor...      11.454248  Positive
# 1  Plenty of room and works and great price. No i...       2.346163  Positive
# 2  Works really well. I use it for my dash cam an...       4.394686  Positive
# 3  The Amazon Basics microSDXC Memory Card with F...       7.200007  Positive
# 4  Nice card good for security cameras , adapters...       2.690539  Positive
#
#    Brand_encode  sentiment_encoded
# 0             5                  2
# 1             5                  2
# 2             5                  2
# 3             5                  2
# 4             5                  2

# %% [markdown]
# Printing First 5 rows data from processed data set

# %%
df.head(5)
# Out:
#    Product Name  Product Price  Product ID          Brand  Rating  \
# 0      4.324424          17.92         356  Amazon Basics     5.0
# 1      4.324424          17.92         356  Amazon Basics     5.0
# 2      4.324424          17.92         356  Amazon Basics     5.0
# 3      4.324424          17.92         356  Amazon Basics     4.0
# 4      4.324424          17.92         356  Amazon Basics     5.0
#
#                                     customer reviews  clean_reviews sentiment  \
# 0  n a world obsessed with flashy brands and exor...      11.454248  Positive
# 1  Plenty of room and works and great price. No i...       2.346163  Positive
# 2  Works really well. I use it for my dash cam an...       4.394686  Positive
# 3  The Amazon Basics microSDXC Memory Card with F...       7.200007  Positive
# 4  Nice card good for security cameras , adapters...       2.690539  Positive
#
#    Brand_encode  sentiment_encoded
# 0             5                  2
# 1             5                  2
# 2             5                  2
# 3             5                  2
# 4             5                  2

# %% [markdown]
# Visualizing Distribution of each column on processed data

# %%
df.drop('customer reviews', axis=1, inplace=True)
x = 'sentiment'
y = 'Brand'
for col in df.columns:
  if col != x and col != y :
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True,palette='viridis')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')
# C:\Users\rotes\AppData\Local\Temp\ipykernel_18848\2768792787.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[col], kde=True,palette='viridis')

# %% [markdown]
# ---
#
#
#
# ---

# %%
numerical_columns = ['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']
scaler = StandardScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
df
# Out:
#       Product Name  Product Price  Product ID           Brand    Rating  \
# 0         0.170316          17.92    0.096136   Amazon Basics  0.446112
# 1         0.170316          17.92    0.096136   Amazon Basics  0.446112
# 2         0.170316          17.92    0.096136   Amazon Basics  0.446112
# 3         0.170316          17.92    0.096136   Amazon Basics -0.783162
# 4         0.170316          17.92    0.096136   Amazon Basics  0.446112
# ...            ...            ...         ...             ...       ...
# 6995      1.453418          91.99   -0.961729       be quiet! -2.012437
# 6996      1.453418          91.99   -0.961729       be quiet!  0.446112
# 6997      0.999366         129.99   -0.982171  LG Electronics  0.446112
# 6998      0.999366         129.99   -0.982171  LG Electronics  0.446112
# 6999      0.999366         129.99   -0.982171  LG Electronics -0.783162
#
#       clean_reviews sentiment  Brand_encode  sentiment_encoded
# 0          1.996340  Positive     -1.175276           0.216282
# 1         -1.188474  Positive     -1.175276           0.216282
# 2         -0.472169  Positive     -1.175276           0.216282
# 3          0.508764  Positive     -1.175276           0.216282
# 4         -1.068056  Positive     -1.175276           0.216282
# ...             ...       ...           ...                ...
# 6995       2.223820  Negative      1.689460          -4.675125
# 6996       1.097662  Positive      1.689460           0.216282
# 6997       1.001912  Positive     -0.229124           0.216282
# 6998      -0.007158  Positive     -0.229124           0.216282
# 6999       1.647354  Positive     -0.229124           0.216282
#
# [6977 rows x 9 columns]

# %% [markdown]
# Copying processed data frame to original data set later use for cluster name shwoing and grouping

# %%
original_df = df.copy()
original_df
# Out:
#       Product Name  Product Price  Product ID           Brand    Rating  \
# 0         0.170316          17.92    0.096136   Amazon Basics  0.446112
# 1         0.170316          17.92    0.096136   Amazon Basics  0.446112
# 2         0.170316          17.92    0.096136   Amazon Basics  0.446112
# 3         0.170316          17.92    0.096136   Amazon Basics -0.783162
# 4         0.170316          17.92    0.096136   Amazon Basics  0.446112
# ...            ...            ...         ...             ...       ...
# 6995      1.453418          91.99   -0.961729       be quiet! -2.012437
# 6996      1.453418          91.99   -0.961729       be quiet!  0.446112
# 6997      0.999366         129.99   -0.982171  LG Electronics  0.446112
# 6998      0.999366         129.99   -0.982171  LG Electronics  0.446112
# 6999      0.999366         129.99   -0.982171  LG Electronics -0.783162
#
#       clean_reviews sentiment  Brand_encode  sentiment_encoded
# 0          1.996340  Positive     -1.175276           0.216282
# 1         -1.188474  Positive     -1.175276           0.216282
# 2         -0.472169  Positive     -1.175276           0.216282
# 3          0.508764  Positive     -1.175276           0.216282
# 4         -1.068056  Positive     -1.175276           0.216282
# ...             ...       ...           ...                ...
# 6995       2.223820  Negative      1.689460          -4.675125
# 6996       1.097662  Positive      1.689460           0.216282
# 6997       1.001912  Positive     -0.229124           0.216282
# 6998      -0.007158  Positive     -0.229124           0.216282
# 6999       1.647354  Positive     -0.229124           0.216282
#
# [6977 rows x 9 columns]

# %% [markdown]
# # **K-Mean Clustering**

# %% [markdown]
# Choosing Best Number of clusters via Elbow method, Silhouette Score Method and Inertia Method
#
#
# *   Dropping Product ID and applying PCA to reduce Data Dimension and then building K-mean Algorithm

# %% [markdown]
# Elbow Method
# * Before that dropping text base column which are sentiment, Brand, Product Price

# %%
df.drop('sentiment', axis=1, inplace=True)
df.drop('Product Price', axis=1, inplace=True)
df.drop('Brand', axis=1, inplace=True)
pca = PCA(n_components=2)


df_pca = pca.fit_transform(df[['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']])
inertia = []
K = range(1, 10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df_pca)
    inertia.append(kmeanModel.inertia_)
plt.figure(figsize=(8,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Elbow_inertia')
plt.title('The Elbow Methods showing the optimal k')
plt.show()
diff = np.diff(inertia)
diff_r = diff[1:] / diff[:-1]
k_opt_elbow = K[np.argmin(diff_r)+1]
print(f"The optimal number of clusters according to the Elbow method is {k_opt_elbow}")
# Out:
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The optimal number of clusters according to the Elbow method is 3

# %% [markdown]
# Silhouette Score Method

# %%
sil = []
K = range(2, 10)
for k in K:
    kmeans = KMeans(n_clusters = k).fit(df_pca)
    labels = kmeans.labels_
    sil.append(silhouette_score(df_pca, labels, metric = 'euclidean'))
plt.figure(figsize=(8,12))
plt.plot(K, sil, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method For Optimal k')
plt.show()
k_opt = K[sil.index(max(sil))]
print(f"The optimal number of clusters is {k_opt}")
# Out:
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The optimal number of clusters is 2

# %% [markdown]
# After checking the silhouette score and elbow method we will try K-mean with 2 clusters and with 3 clusters

# %% [markdown]
# Inertia Method to Find Optimal Number of Clusters

# %%
inertia = []
K = range(1, 10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df_pca)
    inertia.append(kmeanModel.inertia_)
plt.figure(figsize=(8,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('The Inertia Methods showing the optimal k')
plt.show()
diff = np.diff(inertia)
diff_r = diff[1:] / diff[:-1]
k_opt_inertia = K[np.argmin(inertia)]
print(f"The optimal number of clusters according to the Inertia method is {k_opt_inertia}")
# Out:
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The optimal number of clusters according to the Inertia method is 9

# %% [markdown]
# Training K mean on cluster range from 2 to 7

# %%
kmeans_models = {}
silhouette_scores = {}

for i in range(2, 8):  # 2 to 7 clusters
    kmeans = KMeans(n_clusters=i, random_state=45)
    kmeans.fit(df_pca)
    df[f'Cluster_{i}'] = kmeans.labels_
    kmeans_models[i] = kmeans
    silhouette_scores[i] = silhouette_score(df_pca, kmeans.labels_)
# Out:
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# silhouette score to check how well seperated cluster are the higher the score
# is the better the clusters are range between **(-1 -> 1)**
#
#
# *   Checking Score on all generated k-mean cluster

# %%
for clusters, score in silhouette_scores.items():
    print(f"The silhouette score for {clusters} clusters is {score}")
# Out:
# The silhouette score for 2 clusters is 0.7533675065643965
# The silhouette score for 3 clusters is 0.5058469144981425
# The silhouette score for 4 clusters is 0.4422044960948816
# The silhouette score for 5 clusters is 0.38665370502542756
# The silhouette score for 6 clusters is 0.41561603004443715
# The silhouette score for 7 clusters is 0.41252145198436174

# %% [markdown]
# * Visualizing the cluster comparing Kmean with different number of clusters
# * showing the count of data point in clusters

# %%
fig, axs = plt.subplots(3, 2, figsize=(12, 12))
titles = ['2 Clusters', '3 Clusters', '4 Clusters', '5 Clusters', '6 Clusters', '7 Clusters']

for i, (k, kmeans) in enumerate(kmeans_models.items()):
    row = i // 2
    col = i % 2
    df[f'Cluster_{k}'] = kmeans.labels_
    cluster_counts = df[f'Cluster_{k}'].value_counts().sort_index()
    scatter = axs[row, col].scatter(df_pca[:, 0], df_pca[:, 1], c=kmeans.labels_, cmap='viridis')
    axs[row, col].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label='Cluster Centers')
    legend = axs[row, col].legend(handles=scatter.legend_elements()[0], labels=[f'Cluster {i} ({count} points)' for i, count in enumerate(cluster_counts)], loc='upper right')
    axs[row, col].add_artist(legend)
    axs[row, col].set_title(f'KMeans Clustering with {titles[i]}')
    axs[row, col].set_xlabel('Principal Component 1')
    axs[row, col].set_ylabel('Principal Component 2')

plt.tight_layout()
plt.show()

# %% [markdown]
# as we can see the maximum score is at k=2, lets try by visualizing these seperate K-means plot for analysis

# %% [markdown]
# Cluster with Highest Silhoutte Score

# %%
plt.figure(figsize=(5, 5))
kmeans = KMeans(n_clusters=2, random_state=45)
kmeans.fit(df_pca)
df[f'Cluster_{i}'] = kmeans.labels_
kmeans_models[i] = kmeans
df['Cluster'] = kmeans.labels_
cluster_counts = df['Cluster'].value_counts().sort_index()
scatter = plt.scatter(df_pca[:, 0], df_pca[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label='Cluster Centers')
legend = plt.legend(handles=scatter.legend_elements()[0], labels=[f'Cluster {i} ({count} points)' for i, count in enumerate(cluster_counts)], loc='upper right')
plt.gca().add_artist(legend)
plt.title('KMeans Clustering with 2 Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **DBSCAN Clustering**

# %% [markdown]
# Finding the Optimal Eps for DBSCAN Training

# %%
sil = []
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df[['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']])
eps_values = np.arange(0.2, 1.0, 0.1)
for eps in eps_values:
    dbscan = DBSCAN(eps=eps, min_samples=10).fit(df_pca)
    labels = dbscan.labels_
    if len(set(labels)) > 1:
        sil.append(silhouette_score(df_pca, labels, metric='euclidean'))
    else:
        sil.append(-1)
plt.figure(figsize=(16,8))
plt.plot(eps_values, sil, 'bx-')
plt.xlabel('eps')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method For Optimal eps')
plt.show()
eps_best = eps_values[sil.index(max(sil))]
print(f"The best eps is {eps_best}")
# Out:
# The best eps is 0.30000000000000004

# %% [markdown]
# Training model on range of Eps range from 0.2 to 4.5 with step 0.5

# %%
eps_values = np.arange(0.2, 1.0, 0.1)
dbscan_models = []
sil_hou = []
for eps in eps_values:
    dbscan = DBSCAN(eps=eps, min_samples=10)
    dbscan.fit(df_pca)
    dbscan_models.append(dbscan)

# %% [markdown]
# Printing Score for each model

# %%
for i, dbscan in enumerate(dbscan_models):
    if len(set(dbscan.labels_)) > 1:
        sil_score = silhouette_score(df_pca, dbscan.labels_)
        print(f'Silhouette Score with eps={eps_values[i]}: {sil_score}')
# Out:
# Silhouette Score with eps=0.2: 0.0886692411744011
# Silhouette Score with eps=0.30000000000000004: 0.672501370328795
# Silhouette Score with eps=0.4000000000000001: 0.6628911740421851
# Silhouette Score with eps=0.5000000000000001: 0.6677019615931349
# Silhouette Score with eps=0.6000000000000001: 0.624585433292032
# Silhouette Score with eps=0.7000000000000002: 0.6036027144526538
# Silhouette Score with eps=0.8000000000000003: 0.6036027144526538
# Silhouette Score with eps=0.9000000000000001: 0.6036027144526538

# %% [markdown]
# Visualizing the Graph to see the difference

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
for i, dbscan in enumerate(dbscan_models):
    row = i // 3
    col = i % 3
    scatter = axs[row, col].scatter(df_pca[:, 0], df_pca[:, 1], c=dbscan.labels_, cmap='viridis')
    axs[row, col].set_title(f'DBSCAN Clustering with eps={eps_values[i]}')
    axs[row, col].set_xlabel('Principal Component 1')
    axs[row, col].set_ylabel('Principal Component 2')
plt.tight_layout()
plt.show()

# %% [markdown]
# Fitting the DBSCAN Model

# %% [markdown]
# Training DBCSAN with highest Silhoutte score

# %%
dbscan = DBSCAN(eps=0.3, min_samples=10)
dbscan.fit(df_pca)
df['Cluster_DBSCAN'] = dbscan.labels_

# %%
df['Cluster_DBSCAN'].unique()
# Out:
# array([ 0,  1, -1,  2], dtype=int64)

# %% [markdown]
# DBSCAN Silhouette Score

# %%
silhouette_avg = silhouette_score(df_pca, dbscan.labels_)
print("The average silhouette_score is :", silhouette_avg)
# Out:
# The average silhouette_score is : 0.6725013703287542

# %% [markdown]
# Displaying Total Number of Clusters Made from it

# %%
labels = np.unique(df['Cluster_DBSCAN'])
num_clusters = len(labels)
clusters = labels[labels != -1]
num_clusters = len(clusters)
print("Number of clusters formed by DBSCAN (excluding noise points):", num_clusters)
# Out:
# Number of clusters formed by DBSCAN (excluding noise points): 3

# %% [markdown]
# Visualizing the 2D Graph of DBSCAN

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=df['Cluster_DBSCAN'], cmap='viridis')
plt.title('Clusters from DBSCAN')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# Making 3D Graph of the DBSCAN for better Visualization

# %%
pca = PCA(n_components=3)
df_pca = pca.fit_transform(df[['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']])
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df_pca[:, 0], df_pca[:, 1], df_pca[:, 2], c=df['Cluster_DBSCAN'], cmap='viridis')
ax.set_title('3D Scatter Plot of Clusters from DBSCAN')
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **Hierarchical Clustering**

# %% [markdown]
# Finding Optimal number of Clusters for Hierarchical Clustering

# %%
sil = []
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df[['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']])
K = range(2, 10)
for k in K:
    agg_clustering = AgglomerativeClustering(n_clusters=k)
    labels = agg_clustering.fit_predict(df_pca)
    sil.append(silhouette_score(df_pca, labels, metric='euclidean'))
plt.figure(figsize=(16,8))
plt.plot(K, sil, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method For Optimal k')
plt.show()
k_best = K[sil.index(max(sil))]
print(f"The best number of clusters is {k_best}")
# Out:
# The best number of clusters is 2

# %% [markdown]
# Training on the range of clusters from 2 to 5

# %%
n_clusters = range(2, 6)
agg_models = []
for n in n_clusters:
    agg_clustering = AgglomerativeClustering(n_clusters=n)
    agg_clustering.fit(df_pca)
    agg_models.append(agg_clustering)

# %% [markdown]
# Printing all silhoutte score for each model

# %%
for i, agg_clustering in enumerate(agg_models):
    sil_score = silhouette_score(df_pca, agg_clustering.labels_)
    print(f'Silhouette Score with {n_clusters[i]} clusters: {sil_score}')
# Out:
# Silhouette Score with 2 clusters: 0.7539538019671103
# Silhouette Score with 3 clusters: 0.49277747603864813
# Silhouette Score with 4 clusters: 0.41852592061084315
# Silhouette Score with 5 clusters: 0.4188150869876005

# %% [markdown]
# Visualizing 3d Graph for each one

# %%
fig = plt.figure(figsize=(15, 12))
pca = PCA(n_components=3)
df_pca = pca.fit_transform(df[['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']])
titles = ['2 Clusters', '3 Clusters', '4 Clusters', '5 Clusters']
for i, agg_clustering in enumerate(agg_models):
    ax = fig.add_subplot(2, 2, i+1, projection='3d')
    scatter = ax.scatter(df_pca[:, 0], df_pca[:, 1], df_pca[:, 2], c=agg_clustering.labels_, cmap='viridis')
    ax.set_title(f'3D Scatter Plot of Clusters from Hierarchical Clustering with {titles[i]}')
    ax.set_xlabel('Principal Component 1')
    ax.set_ylabel('Principal Component 2')
    ax.set_zlabel('Principal Component 3')
plt.tight_layout()
plt.show()

# %% [markdown]
# Training on the best cluster numbers

# %%
agg_clustering = AgglomerativeClustering(n_clusters=2)
df['Cluster_Hierarchical'] = agg_clustering.fit_predict(df_pca)

# %% [markdown]
# Visualizing 3D Graph for the Clusters

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df_pca[:, 0], df_pca[:, 1], df_pca[:, 2], c=df['Cluster_Hierarchical'], cmap='viridis')
ax.set_title('3D Scatter Plot of Clusters from Hierarchical Clustering')
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
plt.show()

# %% [markdown]
# Heirarchical Clustering Silhouette Score

# %%
silhouette_avg_hierarchical = silhouette_score(df_pca, df['Cluster_Hierarchical'])
print("The average silhouette_score for hierarchical clustering is :", silhouette_avg_hierarchical)
# Out:
# The average silhouette_score for hierarchical clustering is : 0.6836807547291126

# %% [markdown]
# # **The Best Fitting Method**

# %% [markdown]
# After Comparing the Silhoutte Score which are the following:
# * K-means : 0.75
# * DBSCAN :  0.67
# * Hierarchical Clustering: 0.68
#
# *K-means has the highest score*

# %%
df_kmean = pd.DataFrame()
df_kmean['cluster'] = df['Cluster'].copy()
df_kmean['Brand'] = original_df['Brand'].copy()

# %% [markdown]
# Printing K-means clusters and their containing brand in cluster

# %%
df_kmean
clusters = df_kmean.groupby('cluster')['Brand'].unique()

for cluster, brands in clusters.items():
    print(f'Cluster {cluster} contains brands:')
    print(list(brands))
    print()
# Out:
# Cluster 0 contains brands:
# ['Amazon Basics', 'Toshiba', 'SanDisk', 'Seagate', 'SAMSUNG', 'Brother', 'Sceptre', 'Philips', 'TP-Link', 'Western Digital', 'MUXA', 'SteelSeries', 'Dell', 'WD_BLACK', 'PlayStation', 'acer', 'AMD', 'Corsair', 'Elgato', 'NETGEAR', 'AOC', 'Samsung Electronics', 'Square', 'Crucial', 'Jadaol', 'Owl Labs', 'Razer', 'Belkin', 'Post-it', 'Kingston', 'Lovaky', 'E-Z Ink', 'GIGABYTE', 'LG', 'Turtle Beach', 'ViewSonic', 'EMEET', 'Synology', 'Wacom', 'NZXT', 'ASUS', 'Thermaltake', 'SABRENT', 'JanSport', 'Danigh-buy', 'StarTech.com', 'Ozeino', 'PNY', 'BenQ', 'Lexar', 'Lenovo', 'Anker', 'INIU', 'LaCie', 'Cooler Master', 'LG Electronics', 'uni', 'msi', 'HUANUO', 'Verbatim', 'SPARIN', 'SanDisk Professional', 'KOORUI', 'HORI', 'Lian Li', 'Maxell', 'Carhartt', 'Plantronics', 'QGeeM', 'Ontel', 'OtterBox', 'Jabra', 'VEVOR', 'Targus', 'Zyerch', 'Fintie', 'Pyle', 'Poly', 'EVGA', 'SCUF', '8Bitdo', 'SwissGear', 'Koonie', 'ZAGG', 'Nylavee', 'Intel', 'Unitek', 'Philips Computer Monitors', 'THRUSTMASTER', 'Monoprice', 'TechOrbits', 'PowerA', 'GUSGU', 'WALI', 'AMADA HOMEFURNISHING', 'DEEGO', 'Sennheiser US', 'Soqool', 'PNY TECHNOLOGIES', 'Kensington', 'SANSUI', 'Sony', 'Arrow Fastener', 'TRENDnet', 'Noctua', 'DROP', 'WD', 'NVIDIA', 'Linksys', 'Creative', 'Maelstrom', 'be quiet!', 'Next Level Racing', 'MoKo', 'HP Papers', 'Solo New York', 'Corel']
#
# Cluster 1 contains brands:
# ['SteelSeries', 'AMD', 'Brother', 'acer', 'TP-Link', 'SanDisk', 'Dell', 'Razer', 'GIGABYTE', 'LG', 'Turtle Beach', 'Sceptre', 'SAMSUNG', 'EMEET', 'ASUS', 'Amazon Basics', 'Corsair', 'Cooler Master', 'Crucial', 'SanDisk Professional', 'HORI', 'msi', 'QGeeM', 'OtterBox', 'Western Digital', 'KOORUI', 'ViewSonic', 'Jabra', 'Pyle', 'Lenovo', 'Plantronics', 'StarTech.com', 'Poly', 'SCUF', 'ZAGG', 'NETGEAR', 'Unitek', 'THRUSTMASTER', 'PowerA', 'Elgato', 'Belkin', 'AMADA HOMEFURNISHING', 'Square', 'DEEGO', 'Kensington', 'Thermaltake', 'Synology', 'DROP', 'WD', 'NVIDIA', 'Verbatim', 'SABRENT', 'Next Level Racing', 'VEVOR', 'Wacom', 'Solo New York', 'Corel', 'NZXT', 'be quiet!']

# %% [markdown]
# Printing Hierarchical Clustering clusters and their containing brand in cluster

# %%
DF_HC = pd.DataFrame()
DF_HC['cluster'] = df['Cluster_Hierarchical'].copy()
DF_HC['Brand'] = original_df['Brand'].copy()
clusters = DF_HC.groupby('cluster')['Brand'].unique()
for cluster, brands in clusters.items():
    print(f'Cluster {cluster} contains brands:')
    print(list(brands))
    print()
# Out:
# Cluster 0 contains brands:
# ['Amazon Basics', 'Toshiba', 'SanDisk', 'Seagate', 'SAMSUNG', 'Brother', 'Sceptre', 'Philips', 'TP-Link', 'Western Digital', 'MUXA', 'SteelSeries', 'Dell', 'WD_BLACK', 'PlayStation', 'acer', 'AMD', 'Corsair', 'Elgato', 'NETGEAR', 'AOC', 'Samsung Electronics', 'Square', 'Crucial', 'Jadaol', 'Owl Labs', 'Razer', 'Belkin', 'Post-it', 'Kingston', 'Lovaky', 'E-Z Ink', 'GIGABYTE', 'LG', 'Turtle Beach', 'ViewSonic', 'EMEET', 'Synology', 'Wacom', 'NZXT', 'ASUS', 'Thermaltake', 'SABRENT', 'JanSport', 'Danigh-buy', 'StarTech.com', 'Ozeino', 'PNY', 'BenQ', 'Lexar', 'Lenovo', 'Anker', 'INIU', 'LaCie', 'Cooler Master', 'LG Electronics', 'uni', 'msi', 'HUANUO', 'Verbatim', 'SPARIN', 'SanDisk Professional', 'KOORUI', 'HORI', 'Lian Li', 'Maxell', 'Carhartt', 'Plantronics', 'QGeeM', 'Ontel', 'OtterBox', 'Jabra', 'VEVOR', 'Targus', 'Zyerch', 'Fintie', 'Pyle', 'Poly', 'EVGA', 'SCUF', '8Bitdo', 'SwissGear', 'Koonie', 'ZAGG', 'Nylavee', 'Intel', 'Unitek', 'Philips Computer Monitors', 'THRUSTMASTER', 'Monoprice', 'TechOrbits', 'PowerA', 'GUSGU', 'WALI', 'AMADA HOMEFURNISHING', 'DEEGO', 'Sennheiser US', 'Soqool', 'PNY TECHNOLOGIES', 'Kensington', 'SANSUI', 'Sony', 'Arrow Fastener', 'TRENDnet', 'Noctua', 'DROP', 'WD', 'NVIDIA', 'Linksys', 'Creative', 'Maelstrom', 'be quiet!', 'Next Level Racing', 'MoKo', 'HP Papers', 'Solo New York', 'Corel']
#
# Cluster 1 contains brands:
# ['SteelSeries', 'AMD', 'Brother', 'acer', 'TP-Link', 'SanDisk', 'Dell', 'Razer', 'GIGABYTE', 'LG', 'Turtle Beach', 'Sceptre', 'SAMSUNG', 'EMEET', 'ASUS', 'Amazon Basics', 'Corsair', 'Cooler Master', 'Crucial', 'SanDisk Professional', 'HORI', 'msi', 'QGeeM', 'OtterBox', 'Western Digital', 'KOORUI', 'ViewSonic', 'Jabra', 'Pyle', 'Lenovo', 'Plantronics', 'StarTech.com', 'Poly', 'SCUF', 'ZAGG', 'NETGEAR', 'Unitek', 'THRUSTMASTER', 'PowerA', 'Elgato', 'Belkin', 'AMADA HOMEFURNISHING', 'Square', 'DEEGO', 'Kensington', 'Thermaltake', 'Synology', 'DROP', 'WD', 'NVIDIA', 'Verbatim', 'SABRENT', 'Next Level Racing', 'VEVOR', 'Wacom', 'Solo New York', 'Corel', 'NZXT', 'be quiet!']

# %% [markdown]
# Printing DBSCAN clusters and their containing brand in cluster

# %%
DF_dbscan = pd.DataFrame()
DF_dbscan['cluster'] = df['Cluster_DBSCAN'].copy()
DF_dbscan['Brand'] = original_df['Brand'].copy()
clusters = DF_dbscan.groupby('cluster')['Brand'].unique()

for cluster, brands in clusters.items():
    print(f'Cluster {cluster} contains brands:')
    print(list(brands))
    print()
# Out:
# Cluster -1 contains brands:
# ['Brother', 'acer', 'Post-it', 'Dell', 'LG', 'Turtle Beach', 'SAMSUNG', 'Razer', 'SteelSeries', 'Corsair', 'Sceptre', 'ASUS', 'Amazon Basics', 'TP-Link', 'OtterBox', 'KOORUI', 'ViewSonic', 'Lenovo', 'Poly', 'msi', 'Unitek', 'THRUSTMASTER', 'Elgato', 'Belkin', 'AMADA HOMEFURNISHING', 'SCUF', 'DEEGO', 'NETGEAR', 'Kensington', 'Thermaltake', 'GIGABYTE', 'Plantronics', 'NVIDIA', 'Jabra', 'Wacom', 'Solo New York', 'Corel', 'be quiet!']
#
# Cluster 0 contains brands:
# ['Amazon Basics', 'Toshiba', 'SanDisk', 'Seagate', 'SAMSUNG', 'Brother', 'Sceptre', 'Philips', 'TP-Link', 'Western Digital', 'MUXA', 'SteelSeries', 'Dell', 'WD_BLACK', 'PlayStation', 'acer', 'AMD', 'Corsair', 'Elgato', 'NETGEAR', 'AOC', 'Samsung Electronics', 'Square', 'Crucial', 'Jadaol', 'Owl Labs', 'Razer', 'Belkin', 'Post-it', 'Kingston', 'Lovaky', 'E-Z Ink', 'GIGABYTE', 'LG', 'Turtle Beach', 'ViewSonic', 'EMEET', 'Synology', 'Wacom', 'NZXT', 'ASUS', 'Thermaltake', 'SABRENT', 'JanSport', 'Danigh-buy', 'StarTech.com', 'Ozeino', 'PNY', 'BenQ', 'Lexar', 'Lenovo', 'Anker', 'INIU', 'LaCie', 'Cooler Master', 'LG Electronics', 'uni', 'msi', 'HUANUO', 'Verbatim', 'SPARIN', 'SanDisk Professional', 'KOORUI', 'HORI', 'Lian Li', 'Maxell', 'Carhartt', 'Plantronics', 'QGeeM', 'Ontel', 'OtterBox', 'Jabra', 'VEVOR', 'Targus', 'Zyerch', 'Fintie', 'Pyle', 'Poly', 'EVGA', 'SCUF', '8Bitdo', 'SwissGear', 'Koonie', 'ZAGG', 'Nylavee', 'Intel', 'Unitek', 'Philips Computer Monitors', 'THRUSTMASTER', 'Monoprice', 'TechOrbits', 'PowerA', 'GUSGU', 'WALI', 'AMADA HOMEFURNISHING', 'DEEGO', 'Sennheiser US', 'Soqool', 'PNY TECHNOLOGIES', 'Kensington', 'SANSUI', 'Sony', 'Arrow Fastener', 'TRENDnet', 'Noctua', 'DROP', 'WD', 'NVIDIA', 'Linksys', 'Creative', 'Maelstrom', 'be quiet!', 'Next Level Racing', 'MoKo', 'HP Papers', 'Solo New York', 'Corel']
#
# Cluster 1 contains brands:
# ['SteelSeries', 'AMD', 'TP-Link', 'SanDisk', 'Dell', 'Razer', 'GIGABYTE', 'LG', 'Turtle Beach', 'Sceptre', 'SAMSUNG', 'ASUS', 'Amazon Basics', 'Cooler Master', 'Crucial', 'SanDisk Professional', 'HORI', 'msi', 'Brother', 'acer', 'QGeeM', 'Western Digital', 'KOORUI', 'Jabra', 'Corsair', 'Pyle', 'Lenovo', 'Plantronics', 'StarTech.com', 'Poly', 'SCUF', 'ZAGG', 'NETGEAR', 'THRUSTMASTER', 'PowerA', 'Elgato', 'Belkin', 'ViewSonic', 'Square', 'Kensington', 'OtterBox', 'Synology', 'DROP', 'WD', 'NVIDIA', 'Verbatim', 'SABRENT', 'Next Level Racing', 'VEVOR', 'Corel', 'NZXT']
#
# Cluster 2 contains brands:
# ['EMEET', 'KOORUI', 'TP-Link', 'msi', 'Sceptre', 'SAMSUNG', 'Elgato', 'ViewSonic', 'Lenovo', 'ASUS', 'Jabra', 'Cooler Master', 'SanDisk Professional', 'SteelSeries']

# %% [markdown]
# # **Evalution of Best Seletecd Method**

# %%
df_pca = PCA(n_components=2).fit_transform(df[['Brand_encode', 'Product Name','Product ID','clean_reviews','Rating','sentiment_encoded']])
X_train, X_test, y_train, y_test = train_test_split(df_pca, df['Cluster'], test_size=0.2, random_state=45)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.25, random_state=45)
kmeans = KMeans(n_clusters=2, random_state=45)
kmeans.fit(X_train)
valid_pred = kmeans.predict(X_valid)
score = silhouette_score(X_valid, valid_pred)
print(f'Silhouette Score on validation set: {score}')
test_pred = kmeans.predict(X_test)
score_test = silhouette_score(X_test, test_pred)
print(f'Silhouette Score on test set: {score_test}')
comparison = np.where(y_test == test_pred, 'True', 'False')
print(f'Comparison of actual and predicted labels: {comparison}')
# Out:
# Silhouette Score on validation set: 0.7572829032122764
# Silhouette Score on test set: 0.7518968121802179
# Comparison of actual and predicted labels: ['True' 'True' 'True' ... 'True' 'True' 'True']
# c:\Users\rotes\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
